# %% [markdown]
# *yanagi， Updated May 22th*

# %%
# %matplotlib inline

# %% [markdown]
# NLP From Scratch: Translation with a Sequence to Sequence Network and Attention
# *******************************************************************************
# **Original Author**: `Sean Robertson <https://github.com/spro/practical-pytorch>`_
#
# This is the third and final tutorial on doing "NLP From Scratch", where we
# write our own classes and functions to preprocess the data to do our NLP
# modeling tasks. We hope after you complete this tutorial that you'll proceed to
# learn how `torchtext` can handle much of this preprocessing for you in the
# three tutorials immediately following this one.
#
# In this project we will be teaching a neural network to translate from
# English to Chinese.
#
# This is made possible by the simple but powerful idea of the `sequence
# to sequence network <https://arxiv.org/abs/1409.3215>`__, in which two
# recurrent neural networks work together to transform one sequence to
# another. An encoder network condenses an input sequence into a vector,
# and a decoder network unfolds that vector into a new sequence.
#
# ![](https://pytorch.org/tutorials/_images/seq2seq.png)
#
# To improve upon this model we'll use an `attention
# mechanism <https://arxiv.org/abs/1409.0473>`__, which lets the decoder
# learn to focus over a specific range of the input sequence.
#
# **Recommended Reading:**
#
# I assume you have at least installed PyTorch, know Python, and
# understand Tensors:
#
# -  https://pytorch.org/ For installation instructions
# -  :doc:`/beginner/deep_learning_60min_blitz` to get started with PyTorch in general
# -  :doc:`/beginner/pytorch_with_examples` for a wide and deep overview
# -  :doc:`/beginner/former_torchies_tutorial` if you are former Lua Torch user
#
#
# It would also be useful to know about Sequence to Sequence networks and
# how they work:
#
# -  `Learning Phrase Representations using RNN Encoder-Decoder for
#    Statistical Machine Translation <https://arxiv.org/abs/1406.1078>`__
# -  `Sequence to Sequence Learning with Neural
#    Networks <https://arxiv.org/abs/1409.3215>`__
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`__
# -  `A Neural Conversational Model <https://arxiv.org/abs/1506.05869>`__
#
# You will also find the previous tutorials on
# :doc:`/intermediate/char_rnn_classification_tutorial`
# and :doc:`/intermediate/char_rnn_generation_tutorial`
# helpful as those concepts are very similar to the Encoder and Decoder
# models, respectively.
#
# **Requirements**

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import jieba

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of many thousands of English to
# Chinese Mandarin translation pairs.
#
# `This question on Open Data Stack
# Exchange <https://opendata.stackexchange.com/questions/3888/dataset-of-sentences-translated-into-many-languages>`__
# pointed me to the open translation site https://tatoeba.org/ which has
# downloads available at https://tatoeba.org/eng/downloads - and better
# yet, someone did the extra work of splitting language pairs into
# individual text files here: https://www.manythings.org/anki/
#
# The English to Chinese Mandarin pairs are too big to include in the repo, so
# download to ``tchi_en_data/eng-cmn.txt`` before continuing. The file is a tab
# separated list of translation pairs:
#
#
#
# > Even now, I occasionally think I'd like to see you. Not the you that you are today, but the you I remember from the past.
# >
# > 即使是现在，我偶尔还是想见到你。不是今天的你，而是我记忆中曾经的你。

# %% [markdown]
# Similar to the character encoding used in the character-level RNN
# tutorials, we will be representing each word in a language as a one-hot
# vector, or giant vector of zeros except for a single one (at the index
# of the word). Compared to the dozens of characters that might exist in a
# language, there are many many more words, so the encoding vector is much
# larger. We will however cheat a bit and trim the data to only use a few
# thousand words per language.
#
# ![](https://pytorch.org/tutorials/_images/word-encoding.png)

# %% [markdown]
# We'll need a unique index per word to use as the inputs and targets of
# the networks later. To keep track of all this we will use a helper class
# called ``Lang`` which has word → index (``word2index``) and index → word
# (``index2word``) dictionaries, as well as a count of each word
# ``word2count`` which will be used to replace rare words later.

# %%
import jieba

sent = "这本书不错，你是做这份工作最好的人选。"
seg_sent = jieba.cut(sent)
seg_sent = ' '.join(seg_sent)

print(seg_sent)
for word in seg_sent.split(' '):
    print(word)
# Out:
# 这 本书 不错 ， 你 是 做 这份 工作 最好 的 人选 。
# 这
# 本书
# 不错
# ，
# 你
# 是
# 做
# 这份
# 工作
# 最好
# 的
# 人选
# 。

# %%
from ltp import LTP

ltp = LTP(path="./small.tgz")

sent = "这本书不错，你是做这份工作最好的人选。"
segment, _ = ltp.seg([sent])
seg_sent = ' '.join(segment[0])
print(seg_sent)
for word in seg_sent.split(' '):
    print(word)
# Out:
# 这本书 不错 ， 你 是 做 这份 工作 最 好 的 人选 。
# 这本书
# 不错
# ，
# 你
# 是
# 做
# 这份
# 工作
# 最
# 好
# 的
# 人选
# 。

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        # TODO: Chinese word segmentation is different from languages like eng or fra
        if self.name == 'cmn':
            # sentence = jieba.cut(sentence)
            # sentence = ' '.join(sentence)
            sentence, _ = ltp.seg([sentence])
            sentence = ' '.join(sentence[0])

        for word in sentence.split(' '):
            self.addWord(word)

        # if Chinese, then return corresponding segmented squence
        # other language, just return the original one
        return sentence

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# The files are all in Unicode, to simplify we will turn Unicode
# characters to ASCII, make everything lowercase, and trim most
# punctuation.

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

def normalizeChineseString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub("[\r|\n|\\s!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~“”？，！【】（）、。：；’‘……￥·]+", " ", s)
    return s

# %%
normalizeString("Then came the disciples to Jesus apart, and said, Why could not we cast it out?"), normalizeChineseString("识得唔识得，知道了没有？")
# Out:
# ('then came the disciples to jesus apart and said why could not we cast it out ?',
#  '识得唔识得 知道了没有 ')

# %% [markdown]
# To read the data file we will split the file into lines, and then split
# lines into pairs. The files are all English → Other Language, so if we
# want to translate from Other Language → English I added the ``reverse``
# flag to reverse the pairs.

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('tchi_en_data/converted-%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[s for s in l.split('\t')[:2]] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %% [markdown]
# Since there are a *lot* of example sentences and we want to train
# something quickly, we'll trim the data set to only relatively short and
# simple sentences. Here the maximum length is 10 words (that includes
# ending punctuation) and we're filtering to sentences that translate to
# the form "I am" or "He is" etc. (accounting for apostrophes replaced
# earlier).

# %%
MAX_LENGTH = 20

eng_prefixes = (
    "I am ", "I'm ",
    "He is", "He's ",
    "She is", "She's ",
    "You are", "You're ", "You'd ", "You should ", "You can ", "You don't ", "You didn't "
    "We are", "We're ",
    "They are", "They're ",
    "How ", "Who ", "What ", "Why ",
    "Do ", "Don't ", "Can ", "Did ",
    "If ", "As "
)


def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1]) < MAX_LENGTH \
        and \
        p[0].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# The full process for preparing the data is:
#
# -  Read text file and split into lines, split lines into pairs
# -  Normalize text, filter by length and content
# -  Make word lists from sentences in pairs

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse=False)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)

    for pair in pairs:
        pair[0] = normalizeString(pair[0]) 
        # pair[1] = normalizeChineseString(pair[1])

    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        in_sent = input_lang.addSentence(pair[0])
        pair[0] = in_sent
        out_sent = output_lang.addSentence(pair[1])
        pair[1] = out_sent
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('eng', 'cmn', True)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 29155 sentence pairs
# Trimmed to 5346 sentence pairs
# Counting words...
# Counted words:
# eng 2467
# cmn 3543
# ['why do you think that i m thinking about you ?', '你 为什么 会 认为 我 在 想 你 ？']

# %%
len(pairs), output_lang.name, output_lang.index2word
# Out:
# (5346,
#  'cmn',
#  {0: 'SOS',
#   1: 'EOS',
#   2: '我',
#   3: '没事',
#   4: '。',
#   5: '已经',
#   6: '起来',
#   7: '了',
#   8: '为什么',
#   9: '是',
#   10: '？',
#   11: '觉得',
#   12: '很',
#   13: '热',
#   14: '生病',
#   15: '很难过',
#   16: '害羞',
#   17: '湿',
#   18: '谁',
#   19: '赢',
#   20: '不',
#   21: '多',
#   22: '可爱',
#   23: '啊',
#   24: '！',
#   25: '回来',
#   26: '忙',
#   27: '我冷',
#   28: '酷',
#   29: '好',
#   30: '自由',
#   31: '吃饱',
#   32: '在',
#   33: '家里',
#   34: '迷失',
#   35: '病',
#   36: '个子',
#   37: '高',
#   38: '死',
#   39: '现在',
#   40: '就',
#   41: '做',
#   42: '别',
#   43: '哭',
#   44: '他',
#   45: '一个',
#   46: 'DJ',
#   47: '懒',
#   48: '太',
#   49: '可怕',
#   50: '真奇怪',
#   51: '多怪',
#   52: '个',
#   53: '男人',
#   54: '无聊',
#   55: '第一',
#   56: '运气',
#   57: '对的',
#   58: '清醒',
#   59: '对不起',
#   60: '抱歉',
#   61: '累',
#   62: '还',
#   63: '年轻',
#   64: '爱',
#   65: '知道',
#   66: '可以',
#   67: '帮忙',
#   68: '吗',
#   69: '?',
#   70: '担心',
#   71: '别动',
#   72: '不要',
#   73: '动',
#   74: '.',
#   75: '等待',
#   76: '凶',
#   77: '穷',
#   78: '他高',
#   79: '我个头',
#   80: '矮',
#   81: '30',
#   82: '岁',
#   83: '英雄',
#   84: '骗子',
#   85: '买',
#   86: '来',
#   87: '啦',
#   88: '正在',
#   89: '吃',
#   90: '东西',
#   91: '更',
#   92: '快',
#   93: '谦虚',
#   94: '的',
#   95: '单身',
#   96: '困',
#   97: '好胖',
#   98: '哦',
#   99: '三十',
#   100: '十二',
#   101: '我们',
#   102: '男孩',
#   103: '迟到',
#   104: '它',
#   105: '什么',
#   106: '她',
#   107: '您',
#   108: '走',
#   109: '你',
#   110: '去',
#   111: '开始',
#   112: '能',
#   113: '看',
#   114: '汤姆',
#   115: '按',
#   116: '说',
#   117: '的做',
#   118: '别笑',
#   119: '恐慌',
#   120: '停火',
#   121: '不许大叫',
#   122: '微笑',
#   123: '着急',
#   124: '独自',
#   125: '一人',
#   126: '强壮',
#   127: '你们',
#   128: '你好',
#   129: '生活',
#   130: '怎么样',
#   131: '上网',
#   132: '也',
#   133: '17',
#   134: '不成器',
#   135: '人',
#   136: '输家',
#   137: '奴隶',
#   138: '在家',
#   139: '好奇',
#   140: '身体',
#   141: '受伤',
#   142: '开玩笑',
#   143: '结婚',
#   144: '已婚',
#   145: '祈祷',
#   146: '读书',
#   147: '放松',
#   148: '认真',
#   149: '渴',
#   150: '烦死人',
#   151: '可惜',
#   152: '遗憾',
#   153: '真是',
#   154: '有',
#   155: '新鲜事',
#   156: '画',
#   157: '下',
#   158: '那',
#   159: '这',
#   160: '愚蠢',
#   161: '这里',
#   162: '安全',
#   163: '有病',
#   164: '做到',
#   165: '阅读',
#   166: '会',
#   167: '游泳',
#   168: '打',
#   169: '过',
#   170: '电话',
#   171: '吸烟',
#   172: '抽',
#   173: '抽烟',
#   174: '尽力而为',
#   175: '伤心',
#   176: '不用麻烦',
#   177: '别来烦',
#   178: '东拉西扯',
#   179: '出去',
#   180: '真',
#   181: '烦人',
#   182: '糟糕',
#   183: '华人',
#   184: '洗耳恭听',
#   185: '流血',
#   186: '糖尿病',
#   187: '肚子',
#   188: '饿',
#   189: '极了',
#   190: '有空',
#   191: '清白',
#   192: '新来',
#   193: '没',
#   194: '确定',
#   195: '不适',
#   196: '怀孕',
#   197: '改过自新',
#   198: '高兴',
#   199: '好累',
#   200: '最',
#   201: '激动不已',
#   202: '错',
#   203: '安静',
#   204: '心情',
#   205: '不好',
#   206: '它们',
#   207: '假',
#   208: '他们',
#   209: '离开',
#   210: '孩子',
#   211: '她们',
#   212: '已',
#   213: '成年人',
#   214: '藏着',
#   215: '建',
#   216: '想',
#   217: '要',
#   218: '喝醉',
#   219: '撒谎',
#   220: '聪明',
#   221: '给',
#   222: '开车',
#   223: '你会',
#   224: '溜冰',
#   225: '回应',
#   226: '写',
#   227: '认识',
#   228: '懂',
#   229: '懂么',
#   230: '失礼',
#   231: '放弃',
#   232: '!',
#   233: '恨',
#   234: '管',
#   235: '告诉',
#   236: '小偷',
#   237: '菜',
#   238: '傻子',
#   239: '疯',
#   240: '美国人',
#   241: '不在家',
#   242: '呢',
#   243: '多美',
#   244: '离婚',
#   245: '打喷嚏',
#   246: '父亲',
#   247: '爸爸',
#   248: '学生',
#   249: '老师',
#   250: '累死',
#   251: '困死',
#   252: '疲惫',
#   253: '，',
#   254: '妈',
#   255: '节食',
#   256: '就上路',
#   257: '孤单',
#   258: '蠢',
#   259: '还是',
#   260: '很气',
#   261: '中',
#   262: '带',
#   263: '武器',
#   264: '朋友',
#   265: '特别',
#   266: '雇',
#   267: '责备',
#   268: '应该',
#   269: '最好去',
#   270: '吧',
#   271: '坏',
#   272: '你二',
#   273: '这个',
#   274: '帮',
#   275: '看看',
#   276: '那个',
#   277: '坐',
#   278: '做得到',
#   279: '起床',
#   280: '看见',
#   281: '看起来',
#   282: '有钱',
#   283: '怎么',
#   284: '么',
#   285: '讨厌',
#   286: '听得见',
#   287: '喜欢',
#   288: '保证',
#   289: '碰',
#   290: '医生',
#   291: '大',
#   292: '作家',
#   293: '多贵',
#   294: '多少',
#   295: '钱',
#   296: '几',
#   297: '块',
#   298: '时间',
#   299: '过得',
#   300: '多快',
#   301: '呀',
#   302: '得',
#   303: '今天',
#   304: '休息',
#   305: '好人',
#   306: '恐怕',
#   307: '不行',
#   308: '百分之百',
#   309: '赞成',
#   310: '无神论者',
#   311: '后面',
#   312: '叫',
#   313: 'Tom',
#   314: '今天有空',
#   315: '轻易',
#   316: '没名气',
#   317: '出名',
#   318: '贪婪',
#   319: '没有',
#   320: '罪',
#   321: '笨蛋',
#   322: '激动',
#   323: '脱',
#   324: '衣服',
#   325: '素食主义者',
#   326: '快乐',
#   327: '幸福',
#   328: '护士',
#   329: '行走',
#   330: '家庭',
#   331: '正',
#   332: '参与',
#   333: '职业',
#   334: '问',
#   335: '干什么',
#   336: '这儿',
#   337: '女人',
#   338: '醉',
#   339: '喝多',
#   340: '不必',
#   341: '感谢',
#   342: '带上',
#   343: '你那',
#   344: '感觉',
#   345: '得到',
#   346: '找到',
#   347: '吹口哨',
#   348: '说是',
#   349: '拿',
#   350: '肉',
#   351: '经常',
#   352: '说唱',
#   353: '音乐',
#   354: '记得',
#   355: '看电视',
#   356: '被',
#   357: '骗',
#   358: '跟着来',
#   359: '忘',
#   360: '打开',
#   361: '冒险',
#   362: '别说谎',
#   363: '相信',
#   364: '同意',
#   365: '教师',
#   366: '非常',
#   367: '亲切',
#   368: '喜剧演员',
#   369: '高大',
#   370: '生气',
#   371: '大家',
#   372: '如何',
#   373: '多么',
#   374: '有趣',
#   375: '粗鲁',
#   376: '可怜',
#   377: '有麻烦',
#   378: '遇到',
#   379: '困难',
#   380: '侦探',
#   381: '外国人',
#   382: '厨师',
#   383: '夜猫子',
#   384: '大学',
#   385: '教授',
#   386: '快好了',
#   387: '差不多',
#   388: '完成',
#   389: '总是',
#   390: '有事',
#   391: '一直',
#   392: '嚼',
#   393: '口香糖',
#   394: '做白日梦',
#   395: '吃米饭',
#   396: '精神',
#   397: '来自',
#   398: '波士顿',
#   399: '变老',
#   400: '找',
#   401: '工作',
#   402: '左撇子',
#   403: '巫婆',
#   404: '嫉妒',
#   405: '挺',
#   406: '相当',
#   407: '真的',
#   408: '好忙',
#   409: '冷',
#   410: '寂寞',
#   411: '电视',
#   412: '代理人',
#   413: '律师',
#   414: '妹妹',
#   415: '举止',
#   416: '优雅',
#   417: '姊妹',
#   418: '十七',
#   419: '瓜',
#   420: '说话',
#   421: '加拿大人',
#   422: '邻居',
#   423: '惊喜',
#   424: '做什么',
#   425: '少',
#   426: '几点',
#   427: '点',
#   428: '为了什么',
#   429: '豆子',
#   430: '玩',
#   431: '为甚么',
#   432: '失败',
#   433: '进来',
#   434: '最好',
#   435: '天使',
#   436: '你个',
#   437: '呆瓜',
#   438: '含糊不清',
#   439: '脸红',
#   440: '天真',
#   441: '对了',
#   442: '服',
#   443: '一会儿',
#   444: '睡觉',
#   445: '有人',
#   446: '能吃',
#   447: '证明',
#   448: '救汤姆',
#   449: '派',
#   450: '狗叫',
#   451: '试',
#   452: '杀',
#   453: '见',
#   454: '投',
#   455: '票',
#   456: '随心所欲',
#   457: '吃意面',
#   458: '小孩',
#   459: '猫',
#   460: '下雨',
#   461: '雪',
#   462: '住',
#   463: '需要',
#   464: '帮助',
#   465: '拥有',
#   466: '枪支',
#   467: '想要',
#   468: '更多',
#   469: '要米饭',
#   470: '要酒',
#   471: '再',
#   472: '夸张',
#   473: '别开玩笑',
#   474: '别对著',
#   475: '吼',
#   476: '麻烦',
#   477: '不合群',
#   478: '勇敢',
#   479: '生物学家',
#   480: '旁边',
#   481: '刚',
#   482: '这镇上',
#   483: '怎样',
#   484: '报名',
#   485: '参加',
#   486: '计划',
#   487: '太太',
#   488: '长',
#   489: '倒霉',
#   490: '食物',
#   491: '你长',
#   492: '这么',
#   493: '有点',
#   494: '不好奇',
#   495: '记者',
#   496: '翻译',
#   497: '今晚',
#   498: '只是',
#   499: '随便',
#   500: '乞丐',
#   501: '不忙',
#   502: '跟',
#   503: '一样',
#   504: '那么',
#   505: '老板',
#   506: '打电话',
#   507: '站',
#   508: '这边',
#   509: '以你为荣',
#   510: '准备',
#   511: '去死',
#   512: '待著',
#   513: '着',
#   514: '伙伴',
#   515: '如果',
#   516: '时候',
#   517: '女',
#   518: '对',
#   519: '和善',
#   520: '没死',
#   521: '都',
#   522: '同学',
#   523: '地',
#   524: '匆忙',
#   525: '急',
#   526: '不傻',
#   527: '依靠',
#   528: '自己',
#   529: '主意',
#   530: '表达',
#   531: '关于',
#   532: '该',
#   533: '吵醒',
#   534: '决定',
#   535: '那件',
#   536: '事',
#   537: '的包',
#   538: '哈姆雷特',
#   539: '辞职',
#   540: '留下',
#   541: '缺乏',
#   542: '耐心',
#   543: '挡住',
#   544: '路',
#   545: '歌手',
#   546: '傻',
#   547: '敌人',
#   548: '一',
#   549: '口',
#   550: '一下',
#   551: '信任',
#   552: '冷冻',
#   553: '跳绳',
#   554: '借',
#   555: '果汁',
#   556: '手术',
#   557: '喝',
#   558: '啤酒',
#   559: '幸运',
#   560: '车',
#   561: '地图',
#   562: '有没有纸',
#   563: '明白',
#   564: '让',
#   565: '失望',
#   566: '拉',
#   567: '腿',
#   568: '别说',
#   569: '哟',
#   570: '这些',
#   571: '大胃王',
#   572: '怪人',
#   573: '办公桌',
#   574: '前',
#   575: '不过',
#   576: '从',
#   577: '法国',
#   578: '和',
#   579: '同岁',
#   580: '活泼',
#   581: '如意郎君',
#   582: '到',
#   583: '脑子',
#   584: '灵光',
#   585: '复杂',
#   586: '回答',
#   587: '才能',
#   588: '考',
#   589: '测验',
#   590: '旅行',
#   591: '右边',
#   592: '学习',
#   593: '新生',
#   594: '怕死',
#   595: '擅长',
#   596: '运动',
#   597: '牛奶',
#   598: '输',
#   599: '晚餐',
#   600: '一边',
#   601: '全身',
#   602: '酸痛',
#   603: '浴室',
#   604: '女儿',
#   605: '午饭',
#   606: '危险',
#   607: '反对',
#   608: '战争',
#   609: '处于',
#   610: '之中',
#   611: '做饭',
#   612: '看著',
#   613: '老朋友',
#   614: '就是',
#   615: '问题',
#   616: '所在',
#   617: '出岔子',
#   618: '些',
#   619: '听到',
#   620: '怎么办',
#   621: '认为',
#   622: '意思',
#   623: '名字',
#   624: '发明',
#   625: '醒着',
#   626: '白色',
#   627: '说谎',
#   628: '胖',
#   629: '停车',
#   630: '上相',
#   631: '警惕',
#   632: '叫您汤姆',
#   633: '你汤姆',
#   634: '用',
#   635: '笔',
#   636: '回去',
#   637: '原谅',
#   638: '从前',
#   639: '这吗',
#   640: '把',
#   641: '带来',
#   642: '检查',
#   643: '告发',
#   644: '听起来',
#   645: '像是',
#   646: '恋爱',
#   647: '自行车',
#   648: '苹果',
#   649: '飞机',
#   650: '电影',
#   651: '学校',
#   652: '踢',
#   653: '足球',
#   654: '牙龈',
#   655: '吓坏',
#   656: '等著',
#   657: '闹事',
#   658: '错过',
#   659: '公车',
#   660: '胡说',
#   661: '司机',
#   662: '卖鱼',
#   663: '高尔夫球',
#   664: '无情',
#   665: '走路',
#   666: '很快',
#   667: '苍白',
#   668: '吸毒男',
#   669: '靠近',
#   670: '新交',
#   671: '运行',
#   672: '天气',
#   673: '你家里人',
#   674: '还好',
#   675: '独生子',
#   676: '葡萄牙',
#   677: '静冈',
#   678: '六',
#   679: '英尺',
#   680: '怕',
#   681: '狗',
#   682: '总',
#   683: '名',
#   684: '电工',
#   685: '新加坡',
#   686: '结束',
#   687: '进城',
#   688: '正要',
#   689: '签到',
#   690: '滑雪',
#   691: '网球',
#   692: '才',
#   693: '失去',
#   694: '控制',
#   695: '制作',
#   696: '独裁者',
#   697: '死板的',
#   698: '不感兴趣',
#   699: '舒服',
#   700: '阳台',
#   701: '上',
#   702: '出发',
#   703: '来晚',
#   704: '不能',
#   705: '个内八字',
#   706: '姐妹',
#   707: '姐姐',
#   708: '满意',
#   709: '破产',
#   710: '保守',
#   711: '面包',
#   712: '好朋友',
#   713: '午餐',
#   714: '钢笔',
#   715: '强',
#   716: '风',
#   717: '白痴',
#   718: '搞',
#   719: '打算',
#   720: '老虎',
#   721: '发生',
#   722: '然后',
#   723: '刚刚',
#   724: '将',
#   725: '那些',
#   726: '家伙',
#   727: '那人',
#   728: '枪',
#   729: '干嘛在乎',
#   730: '兴奋',
#   731: '那里',
#   732: '受到',
#   733: '邀请',
#   734: '吓',
#   735: '最好快点',
#   736: '乐观主义者',
#   737: '仍然',
#   738: '小屁孩',
#   739: '一些',
#   740: '茶水',
#   741: '来得及',
#   742: '搓',
#   743: '一下背好',
#   744: '打汤姆',
#   745: '小报告',
#   746: '咖啡',
#   747: '教堂',
#   748: '咳嗽',
#   749: '发烧',
#   750: '有刀',
#   751: '记',
#   752: '日记',
#   753: '英语',
#   754: '橙子',
#   755: '兔子',
#   756: '菠菜',
#   757: '共',
#   758: '房间',
#   759: '讲',
#   760: '法语',
#   761: '愿意',
#   762: '等',
#   763: '掉',
#   764: '杯子',
#   765: '听',
#   766: '身边',
#   767: '不冷',
#   768: '教养',
#   769: '橄榄球',
#   770: '位',
#   771: '信教',
#   772: '演奏',
#   773: '散步',
#   774: '英俊',
#   775: '日本',
#   776: '少年',
#   777: '怕狗',
#   778: '笑',
#   779: '全力以赴',
#   780: '厨房',
#   781: '俄罗斯',
#   782: '方块',
#   783: '比',
#   784: '长子',
#   785: '年长',
#   786: '儿子',
#   787: '想念',
#   788: '泰国菜',
#   789: '联系',
#   790: '连络',
#   791: '远',
#   792: '这间',
#   793: '动物园',
#   794: '多久',
#   795: '钓鱼',
#   796: '研讨会',
#   797: '夏天',
#   798: '订婚',
#   799: '东京',
#   800: '助手',
#   801: '社会',
#   802: '人员',
#   803: '外地人',
#   804: '同年',
#   805: '指望',
#   806: '为',
#   807: '着迷',
#   808: '疯狂',
#   809: '唱歌',
#   810: '好听',
#   811: '一点',
#   812: '警察',
#   813: '妈妈',
#   814: '母亲',
#   815: '屋顶',
#   816: '画画',
#   817: '感到',
#   818: '骄傲',
#   819: '没有你我',
#   820: '悲伤',
#   821: '厌倦',
#   822: '困住',
#   823: '条理',
#   824: '大约',
#   825: '我同年纪',
#   826: '小',
#   827: '女孩',
#   828: '戴',
#   829: '著',
#   830: '顶',
#   831: '帽子',
#   832: '不理我',
#   833: '终于',
#   834: '剩下',
#   835: '紧张',
#   836: '荒唐',
#   837: '故事',
#   838: '吃什么',
#   839: '掩饰',
#   840: '做甚么',
#   841: '不行会',
#   842: '桌子',
#   843: '这种',
#   844: '事情',
#   845: '想要甚么',
#   846: '老男人',
#   847: '请问',
#   848: '那样',
#   849: '不做',
#   850: '天',
#   851: '蓝',
#   852: '很对',
#   853: '可以住口',
#   854: '试试',
#   855: '令人',
#   856: '难以',
#   857: '抗拒',
#   858: '晚',
#   859: '漂亮',
#   860: '囚犯',
#   861: '大方',
#   862: '努力',
#   863: '牵',
#   864: '手',
#   865: '猜到',
#   866: '年龄',
#   867: '您会',
#   868: '骑马',
#   869: '错过派对了',
#   870: 'Tom有',
#   871: '玛丽',
#   872: '猫粮',
#   873: '早',
#   874: '黑洞',
#   875: '存在',
#   876: '别处去',
#   877: '常常',
#   878: '外食',
#   879: '是否',
#   880: '恶心呕吐',
#   881: '六点',
#   882: '照相机',
#   883: '车库',
#   884: '铅笔',
#   885: '兄弟',
#   886: '耳鸣',
#   887: '了解',
#   888: '购物',
#   889: '每天',
#   890: '跑步',
#   891: '学',
#   892: '粗心',
#   893: '幼稚',
#   894: '像',
#   895: '猪',
#   896: '猛吃',
#   897: '走极端',
#   898: '书',
#   899: '阻止',
#   900: '岁数',
#   901: '年纪',
#   902: '与',
#   903: '同在',
#   904: '生',
#   905: '气',
#   906: '充满',
#   907: '活力',
#   908: '图书馆',
#   909: '里',
#   910: '做曲奇',
#   911: '敏感',
#   912: '手套',
#   913: '网球球手',
#   914: '准会',
#   915: '迷住',
#   916: '三明治',
#   917: '怎么能',
#   918: '那么说',
#   919: '洞',
#   920: '深',
#   921: '见到',
#   922: '发胖',
#   923: '富士山',
#   924: '出价',
#   925: '付',
#   926: '这支',
#   927: '这支笔',
#   928: '周末',
#   929: '四点',
#   930: '玉米过敏',
#   931: '老实人',
#   932: '职员',
#   933: '辆',
#   934: '新车',
#   935: '关门',
#   936: '回家路上',
#   937: '受够',
#   938: '叠',
#   939: '连衣裙',
#   940: '出差',
#   941: '赶时间',
#   942: '爱上',
#   943: '大众脸',
#   944: '英文',
#   945: '根本',
#   946: '数学',
#   947: '打棒球',
#   948: '伤害',
#   949: '新手',
#   950: '跳舞',
#   951: '写腻',
#   952: '一起',
#   953: '乐意',
#   954: '分享',
#   955: '舞者',
#   956: '真正',
#   957: '美人',
#   958: '女朋友',
#   959: '打网球',
#   960: '害怕',
#   961: '艺术家',
#   962: '乘',
#   963: '火车',
#   964: '市里',
#   965: '怀疑',
#   966: '煮',
#   967: '包含',
#   968: '到底',
#   969: '回事',
#   970: '这件',
#   971: '目前',
#   972: '占上风',
#   973: '秘书',
#   974: '脑袋',
#   975: '找不到',
#   976: '逃走',
#   977: '何不',
#   978: '回家',
#   979: '抱',
#   980: '不可',
#   981: '懦夫',
#   982: '大人',
#   983: '寄',
#   984: '希望',
#   985: '于',
#   986: '此',
#   987: '握住',
#   988: '使用',
#   989: '这辆',
#   990: '你不配',
#   991: '道歉',
#   992: '这事',
#   993: '领导人',
#   994: '注定',
#   995: '过分',
#   996: '胆小鬼',
#   997: '唯一',
#   998: '傻瓜',
#   999: '这只',
#   ...})

# %% [markdown]
# The Seq2Seq Model
# =================
#
# A Recurrent Neural Network, or RNN, is a network that operates on a
# sequence and uses its own output as input for subsequent steps.
#
# A `Sequence to Sequence network <https://arxiv.org/abs/1409.3215>`__, or
# seq2seq network, or `Encoder Decoder
# network <https://arxiv.org/pdf/1406.1078v3.pdf>`__, is a model
# consisting of two RNNs called the encoder and decoder. The encoder reads
# an input sequence and outputs a single vector, and the decoder reads
# that vector to produce an output sequence.
#
#
# ![](https://pytorch.org/tutorials/_images/seq2seq.png)
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for translation between two
# languages.
#
# Consider the sentence "Je ne suis pas le chat noir" → "I am not the
# black cat". Most of the words in the input sentence have a direct
# translation in the output sentence, but are in slightly different
# orders, e.g. "chat noir" and "black cat". Because of the "ne/pas"
# construction there is also one more word in the input sentence. It would
# be difficult to produce a correct translation directly from the sequence
# of input words.
#
# With a seq2seq model the encoder creates a single vector which, in the
# ideal case, encodes the "meaning" of the input sequence into a single
# vector — a single point in some N dimensional space of sentences.

# %% [markdown]
# The Encoder
# -----------
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.
#
#
# ![](https://pytorch.org/tutorials/_images/encoder-network.png)

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# The Decoder
# -----------
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to create the translation.

# %% [markdown]
# **Simple Decoder**
#
#
# In the simplest seq2seq decoder we use only last output of the encoder.
# This last output is sometimes called the *context vector* as it encodes
# context from the entire sequence. This context vector is used as the
# initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and
# hidden state. The initial input token is the start-of-string ``<SOS>``
# token, and the first hidden state is the context vector (the encoder's
# last hidden state).
#
#
# ![](https://pytorch.org/tutorials/_images/decoder-network.png)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        flag = (output[0] == output[-1], output.shape)
        output = self.softmax(self.out(output[0]))
        return output, hidden, flag

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
dummy_decoder = DecoderRNN(hidden_size=10, output_size=20).to(device)
decoder_input = torch.tensor([[SOS_token]], device=device)
dummy_hidden = dummy_decoder.initHidden()

dummy_output, dummy_hidden, flag = dummy_decoder(decoder_input, dummy_hidden)
print(dummy_output.shape, dummy_hidden.shape, "\n", dummy_output, dummy_hidden)
print(flag)
# sm_fn = nn.LogSoftmax(dim=1)
# print(sm_fn(dummy_output[0]))
# Out:
# torch.Size([1, 20]) torch.Size([1, 1, 10])
#  tensor([[-3.1074, -2.9712, -3.5386, -2.9171, -3.0443, -2.6645, -3.0922, -3.0808,
#          -3.2284, -2.9022, -2.8522, -3.0992, -2.7749, -3.1728, -3.3340, -2.8807,
#          -2.7400, -2.9143, -2.7274, -3.3587]], device='cuda:0',
#        grad_fn=<LogSoftmaxBackward>) tensor([[[ 0.2104,  0.1032, -0.3097, -0.1587,  0.0104, -0.3292,  0.1802,
#            0.2372, -0.2702, -0.0758]]], device='cuda:0',
#        grad_fn=<CudnnRnnBackward>)
# (tensor([[True, True, True, True, True, True, True, True, True, True]],
#        device='cuda:0'), torch.Size([1, 1, 10]))

# %% [markdown]
# I encourage you to train and observe the results of this model, but to
# save space we'll be going straight for the gold and introducing the
# Attention Mechanism.

# %% [markdown]
# **Attention Decoder**
#
# If only the context vector is passed between the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to "focus" on a different part of
# the encoder's outputs for every step of the decoder's own outputs. First
# we calculate a set of *attention weights*. These will be multiplied by
# the encoder output vectors to create a weighted combination. The result
# (called ``attn_applied`` in the code) should contain information about
# that specific part of the input sequence, and thus help the decoder
# choose the right output words.
#
# Calculating the attention weights is done with another feed-forward
# layer ``attn``, using the decoder's input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.
#
# ![](https://pytorch.org/tutorials/_images/attention-decoder-network.png)

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        # output = F.log_softmax(self.out(output[-1]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# <div class="alert alert-info"><h4>Note</h4><p>There are other forms of attention that work around the length
#   limitation by using a relative position approach. Read about "local
#   attention" in `Effective Approaches to Attention-based Neural Machine
#   Translation <https://arxiv.org/abs/1508.04025>`__.</p></div>
#
# Training
# ========
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
fake_input_tensor, fake_target_tensor = tensorsFromPair(['you re even taller than i am .', '您 比 我 更 高 。'])

print("shape:", fake_input_tensor.shape, "\n", "input:", fake_input_tensor)
print("shape:", fake_target_tensor.shape, "\n", "output:", fake_target_tensor)
# Out:
# shape: torch.Size([9, 1])
#  input: tensor([[ 89],
#         [ 83],
#         [617],
#         [661],
#         [662],
#         [  2],
#         [ 46],
#         [  5],
#         [  1]], device='cuda:0')
# shape: torch.Size([7, 1])
#  output: tensor([[107],
#         [783],
#         [  2],
#         [ 91],
#         [ 37],
#         [  4],
#         [  1]], device='cuda:0')

# %% [markdown]
# Training the Model
# ------------------
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the ``<SOS>`` token as its first input, and the last hidden state of the
# encoder as its first hidden state.
#
# "Teacher forcing" is the concept of using the real target outputs as
# each next input, instead of using the decoder's guess as the next input.
# Using teacher forcing causes it to converge faster but `when the trained
# network is exploited, it may exhibit
# instability <http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.378.4095&rep=rep1&type=pdf>`__.
#
# You can observe outputs of teacher-forced networks that read with
# coherent grammar but wander far from the correct translation -
# intuitively it has learned to represent the output grammar and can "pick
# up" the meaning once the teacher tells it the first few words, but it
# has not properly learned how to create the sentence from the translation
# in the first place.
#
# Because of the freedom PyTorch's autograd gives us, we can randomly
# choose to use teacher forcing or not with a simple if statement. Turn
# ``teacher_forcing_ratio`` up to use more of it.

# %%
teacher_forcing_ratio = 0.5

def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %% [markdown]
# This is a helper function to print time elapsed and estimated time
# remaining given the current time and progress %.

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# The whole training process looks like this:
#
# -  Start a timer
# -  Initialize optimizers and criterion
# -  Create set of training pairs
# -  Start empty losses array for plotting
#
# Then we call ``train`` many times and occasionally print the progress (%
# of examples, time so far, estimated time) and average loss.

# %% [markdown]
# Plotting results
# ----------------
#
# Plotting is done with matplotlib, using the array of loss values
# ``plot_losses`` saved while training.

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure(figsize=(9, 5))
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    # encoder_optimizer = optim.AdamW(encoder.parameters(), lr=learning_rate)
    # decoder_optimizer = optim.AdamW(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder's predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder's
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %% [markdown]
# We can evaluate random sentences from the training set and print out the
# input, target, and output to make some subjective quality judgements:

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %% [markdown]
# Training and Evaluating
# =======================
#
# With all these helper functions in place (it looks like extra work, but
# it makes it easier to run multiple experiments) we can actually
# initialize a network and start training.
#
# Remember that the input sentences were heavily filtered. For this small
# dataset we can use relatively small networks of 256 hidden nodes and a
# single GRU layer. After about 40 minutes on a MacBook CPU we'll get some
# reasonable results.
#
# .. Note::
#    If you run this notebook you can train, interrupt the kernel,
#    evaluate, and continue training later. Comment out the lines where the
#    encoder and decoder are initialized and run ``trainIters`` again.

# %%
# %matplotlib inline

hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

trainIters(encoder1, attn_decoder1, 100000, print_every=5000)
# Out:
# 3m 13s (- 61m 9s) (5000 5%) 3.9656
# 5m 53s (- 53m 3s) (10000 10%) 3.3821
# 8m 37s (- 48m 50s) (15000 15%) 2.9000
# 11m 29s (- 45m 58s) (20000 20%) 2.5270
# 14m 23s (- 43m 9s) (25000 25%) 2.1622
# 17m 7s (- 39m 58s) (30000 30%) 1.9089
# 20m 20s (- 37m 46s) (35000 35%) 1.6755
# 23m 10s (- 34m 45s) (40000 40%) 1.4811
# 25m 40s (- 31m 23s) (45000 45%) 1.2738
# 28m 13s (- 28m 13s) (50000 50%) 1.1270
# 30m 50s (- 25m 13s) (55000 55%) 1.0046
# 33m 27s (- 22m 18s) (60000 60%) 0.8907
# 36m 3s (- 19m 24s) (65000 65%) 0.7971
# 38m 38s (- 16m 33s) (70000 70%) 0.7333
# 41m 8s (- 13m 42s) (75000 75%) 0.6526
# 43m 44s (- 10m 56s) (80000 80%) 0.5980
# 46m 33s (- 8m 13s) (85000 85%) 0.5520
# 49m 22s (- 5m 29s) (90000 90%) 0.5042
# 52m 11s (- 2m 44s) (95000 95%) 0.4833
# 54m 42s (- 0m 0s) (100000 100%) 0.4820

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# > how long are you going to stay in japan ?
# = 你 会 待在 日本 多久 ？
# < 你 会 在 日本 多久 ? <EOS>
#
# > can you drive ?
# = 您 会 开车 吗 ？
# < 您 会 开车 吗 ？ <EOS>
#
# > can i use my medical insurance ?
# = 我 可以 使用 我 的 医疗 保险 吗 ？
# < 我 可以 使用 我 的 医疗 保险 吗 ？ <EOS>
#
# > we re going to have to change our plans .
# = 我们 快要 到 必须 改变 我们 计划 的 时候 了 。
# < 我们 快要 到 必须 改变 我们 计划 的 时候 了 。 <EOS>
#
# > what do you think about this ?
# = 你 对 这 件 事 有 什么 看法 ？
# < 你 怎么 看待 这件 事 ？ <EOS>
#
# > i am not curious .
# = 我 不好奇 。
# < 我 不好奇 。 <EOS>
#
# > they re armed .
# = 他们 有 带 武器 。
# < 他们 有 带 武器 。 <EOS>
#
# > if you get sleepy just tell me .
# = 困 了 的话 就 说 哦 。
# < 困 了 的话 就 说 哦 。 <EOS>
#
# > you re too young to retire .
# = 你 太 年轻 ， 不能 退休 。
# < 你 太 年轻 ， 不能 退休 了 。 <EOS>
#
# > don t you agree ?
# = 你 不 同意 吗 ？
# < 你 不 同意 吗 ？ <EOS>

# %% [markdown]
# Visualizing Attention
# ---------------------
#
# A useful property of the attention mechanism is its highly interpretable
# outputs. Because it is used to weight specific encoder outputs of the
# input sequence, we can imagine looking where the network is focused most
# at each time step.
#
# You could simply run ``plt.matshow(attentions)`` to see attention output
# displayed as a matrix, with the columns being input steps and rows being
# output steps:

# %%
# %matplotlib inline

output_words, attentions = evaluate(
    encoder1, attn_decoder1, "what do you suppose this could be ?")
plt.matshow(attentions.numpy())

# %% [markdown]
# For a better viewing experience we will do the extra work of adding axes
# and labels:

# %%
import matplotlib as mpl
mpl.rcdefaults() 

def showAttention(input_sentence, output_words, attentions):
    mpl.rcParams['font.family'] = 'SimHei'
    # Set up figure with colorbar
    fig = plt.figure(figsize=(9, 5))
    
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words, family='SimHei')

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()


def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions)

# %%
evaluateAndShowAttention("how long are you going to stay in japan ?")
evaluateAndShowAttention("what do you think about this ?")
evaluateAndShowAttention("you re too young to retire .")
# Out:
# input = how long are you going to stay in japan ?
# output = 你 会 在 日本 多久 ? <EOS>
# /tmp/ipykernel_1516/2634899092.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + input_sentence.split(' ') +
# /tmp/ipykernel_1516/2634899092.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + output_words, family='SimHei')
# input = what do you think about this ?
# output = 你 怎么 看待 这件 事 ？ <EOS>
# input = you re too young to retire .
# output = 你 太 年轻 ， 不能 退休 了 。 <EOS>

# %% [markdown]
# Postprocessing and computing BLEU
# =================

# %%
import sacrebleu
from typing import List, Tuple, Dict, Set, Union

def compute_corpus_level_bleu_score(references: List[List[str]], hypotheses: List[List[str]]) -> float:
    """ Given decoding results and reference sentences, compute corpus-level BLEU score.
    @returns bleu_score: corpus-level BLEU score
    """
    
    # remove the start and end tokens
    if references[0][0] == '<s>':
        references = [ref[1:-1] for ref in references]
    
    # detokenize the subword pieces to get full sentences
    detokened_refs = [''.join(pieces).replace('▁', ' ') for pieces in references]
    detokened_hyps = [''.join(hyp).replace('▁', ' ') for hyp in hypotheses]

    # sacreBLEU can take multiple references (golden example per sentence) but we only feed it one
    bleu = sacrebleu.corpus_bleu(detokened_hyps, [detokened_refs])

    return bleu.score

# %%
ref_chi = [["你 对 这 件 事 有 什么 看法 ？",], ["我 只是 听到 了 一些 消息 。"]]
hyp_chi = [["你 怎么 看待 这件 事 ？",], ["我 只是 听到 了 一些 消息 。"]]

print(ref_chi, hyp_chi)
compute_corpus_level_bleu_score(ref_chi, hyp_chi), compute_corpus_level_bleu_score(ref_chi, ref_chi)
# Out:
# [['你 对 这 件 事 有 什么 看法 ？'], ['我 只是 听到 了 一些 消息 。']] [['你 怎么 看待 这件 事 ？'], ['我 只是 听到 了 一些 消息 。']]
# (47.96278151321637, 100.00000000000004)

# %%
hyp_chi, ref_chi = [], []
for pair in pairs:
    output_words, _ = evaluate(encoder1, attn_decoder1, pair[0])
    hyp_chi.append(' '.join(output_words[:-1]))
    ref_chi.append(pair[1])

len(pairs), len(hyp_chi), len(ref_chi), hyp_chi[-42][:], ref_chi[-42][:]
# Out:
# (5346, 5346, 5346, '你 最好 带 带 把伞 。', '以防下雨 你 最好 带 把伞 。')

# %%
compute_corpus_level_bleu_score(ref_chi, hyp_chi)
# Out:
# 79.8125146778428

# %%
with open("chi_eng_result.txt", "w", encoding="utf-8") as f:
    for hyp, ref in zip(hyp_chi, ref_chi):
        line =  hyp + "|" + "\t" + ref
        f.write(line + "\n")

# %%
with open("chi_eng_result.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()
    print(lines)
# Out:
# ['我 没事 。|\t我 没事 。\n', '我 也 了 。|\t我 已经 起来 了 。\n', '为什么 没有人 我 ？|\t为什么 是 我 ？\n', '我 觉得 很 热 。|\t我 觉得 很 热 。\n', '我 生病 了 。|\t我 生病 了 。\n', '我 很难过 。|\t我 很难过 。\n', '我 很 害羞 。|\t我 很 害羞 。\n', '我 湿 了 。|\t我 湿 了 。\n', '谁 赢 了 ？ ？|\t谁 赢 了 ？\n', '为什么 不 ？|\t为什么 不 ？\n', '多 可爱 啊 ！|\t多 可爱 啊 ！\n', '我 回来 了 ！|\t我 回来 了 ！\n', '我 很 忙 。|\t我 很 忙 。\n', '我冷 。|\t我冷 。\n', '我 很 酷 。|\t我 很 酷 。\n', '我 很 好 。|\t我 很 好 。\n', '我 自由 了 ！|\t我 自由 了 ！\n', '我 吃饱 了 。|\t我 吃饱 了 。\n', '我 在 家里 。|\t我 在 家里 。\n', '我 迷失 了 。|\t我 迷失 了 。\n', '我 生病 了 。|\t我 生病 了 。\n', '我 生病 了 。|\t我 病 了 。\n', '我 个子 高 。|\t我 个子 高 。\n', '谁 死 了 ？|\t谁 死 了 ？\n', '现在 就 做 。|\t现在 就 做 。\n', '别 哭 。|\t别 哭 。\n', '他 是 一个 DJ 。|\t他 是 一个 DJ 。\n', '他 很 忙 。|\t他 很 忙 。\n', '他 很 懒 。|\t他 很 懒 。\n', '太 可怕 了 。|\t太 可怕 了 。\n', '真奇怪 。|\t真奇怪 。\n', '真奇怪 。|\t多怪 啊 ！\n', '我冷 。|\t我冷 。\n', '我 吃饱 了 。|\t我 吃饱 了 。\n', '我 没事 。|\t我 没事 。\n', '我 生病 了 。|\t我 生病 了 。\n', '我 个子 。|\t我 个子 高 。\n', '我 是 个 男人 。|\t我 是 个 男人 。\n', '我 很 很 很 。 。|\t我 觉得 很 无聊 。\n', '我 是 第一 。|\t我 是 第一 。\n', '我 很 好 。|\t我 运气 很 好 。\n', '我 是 对的 。|\t我 是 对的 。\n', '我 很 清醒 。|\t我 很 清醒 。\n', '我 很 抱歉 。|\t对不起 。\n', '我 很 抱歉 。|\t我 很 抱歉 。\n', '我 很 累 。|\t我 很 累 。\n', '我 还 年轻 。|\t我 还 年轻 。\n', '爱 谁 谁 谁 谁 谁 谁 ？|\t爱 谁 谁 。\n', '谁 知道 ？|\t谁 知道 ？\n', '我 能 帮忙 吗 ?|\t我 可以 帮忙 吗 ?\n', '别 担心 。|\t别 担心 。\n', '不要 恐慌 ！|\t别动 ！\n', '不要 动 。|\t不要 动 。\n', '不要 动 。|\t不要 动 .\n', '不要 等待 ！|\t不要 等待 ！\n', '他 是 一个 DJ 。|\t他 是 一个 DJ 。\n', '他 很 忙 。|\t他 很 忙 。\n', '他 很 懒 。|\t他 很 懒 。\n', '他 很 凶 。|\t他 很 凶 。\n', '他 很 穷 。|\t他 很 穷 。\n', '他高 。|\t他高 。\n', '多 可爱 啊 ！|\t多 可爱 啊 ！\n', '我 是 个 男人 。|\t我 是 个 男人 。\n', '我个头 矮 。|\t我个头 矮 。\n', '我 现在 30 岁 了 。|\t我 现在 30 岁 了 。\n', '我 是 个 英雄 。|\t我 是 个 英雄 。\n', '我 是 个 骗子 。|\t我 是 个 骗子 。\n', '我 买 了 。|\t我 买 了 。\n', '我 来 了 。|\t我 来 啦 。\n', '我 正在 吃 东西 。|\t我 正在 吃 东西 。\n', '我 更 快 。|\t我 更 快 。\n', '我 是 谦虚 的 。|\t我 是 谦虚 的 。\n', '我 单身 。|\t我 单身 。\n', '我 单身 。|\t我 单身 。\n', '我 困 了 。|\t我 困 了 。\n', '我 好胖 哦 。|\t我 好胖 哦 。\n', '我 三十 岁 。|\t我 三十 岁 。\n', '我 十二 岁 了 。|\t我 十二 岁 了 。\n', '我们 是 男孩 。|\t我们 是 男孩 。\n', '我们 迟到 了 。|\t我们 迟到 了 。\n', '它 是 什么 ？|\t它 是 什么 ？\n', '我们 是 谁 ？|\t我们 是 谁 ？\n', '她 是 谁 ？|\t她 是 谁 ？\n', '你 可以 去 了 。|\t您 可以 走 了 。\n', '你 可以 去 了 。|\t你 可以 去 了 。\n', '我 可以 开始 了 吗 ？|\t我 可以 开始 了 吗 ？\n', '我 可以 用 吗 ？|\t我 可以 开始 了 吗 ？\n', '你 能 看 吗 ？|\t你 能 看 吗 ？\n', '汤姆 赢 了 吗 ？|\t汤姆 赢 了 吗 ？\n', '按 我 说 的做 。|\t按 我 说 的做 。\n', '别笑 ！|\t别笑 ！\n', '别 走 ！|\t别 走 ！\n', '不要 恐慌 ！|\t不要 恐慌 ！\n', '停火 。|\t停火 。\n', '不许大叫 。|\t不许大叫 。\n', '不要 微笑 。|\t不要 微笑 。\n', '别 担心 。|\t你 不要 着急 。\n', '别 担心 你 。|\t别 担心 。\n', '别 担心 。|\t别 担心 。\n', '他 独自 。|\t他 独自 一人 。\n', '他 是 个 骗子 。|\t他 是 个 骗子 。\n', '他 很 强壮 。|\t他 很 强壮 。\n', '你 好 吗 ？|\t你们 好 吗 ？\n', '你 好 ？|\t你好 吗 ？\n', '真奇怪 。|\t真奇怪 。\n', '真奇怪 。|\t多怪 啊 ！\n', '生活 怎么样 ？|\t生活 怎么样 ？\n', '真奇怪 。|\t真奇怪 。\n', '我 来 了 。|\t我 来 了 。\n', '我 上网 了 。|\t我 上网 了 。\n', '我 也 是 17 岁 了 。|\t我 也 是 17 岁 。\n', '我 是 个 不成器 的 。|\t我 是 个 不成器 的 人 。\n', '我 是 个 不成器 的 。|\t我 是 个 输家 。\n', '我 是 个 奴隶 。|\t我 是 个 奴隶 。\n', '我 在 家里 。|\t我 在家 。\n', '我 在 家里 。|\t我 在 家里 。\n', '我 很 好奇 。|\t我 很 好奇 。\n', '我 身体 很 好 。|\t我 身体 很 好 。\n', '我 受伤 了 。|\t我 受伤 了 。\n', '我 开玩笑 。|\t我 开玩笑 。\n', '我 已婚 。|\t我 结婚 了 。\n', '我 已婚 。|\t我 已婚 。\n', '我 在 祈祷 。|\t我 在 祈祷 。\n', '我 在 读书 。|\t我 在 读书 。\n', '我 很 放松 。|\t我 很 放松 。\n', '我 是 认真 的 。|\t我 是 认真 的 。\n', '我 渴 了 。|\t我 渴 了 。\n', '我 受伤 了 。|\t我 受伤 了 。\n', '烦死人 。|\t烦死人 。\n', '可惜 可惜 。|\t太 可惜 了 ！\n', '可惜 可惜 了 。|\t可惜 。\n', '可惜 可惜 可惜 。|\t多 遗憾 啊 ！\n', '可惜 可惜 可惜 。|\t真是 太 可惜 了 ！\n', '有 是 什么 ？|\t有 什么 新鲜事 吗 ？\n', '你 是 谁 ？|\t你 是 谁 ？\n', '你 是 谁 ？|\t你 是 谁 ？\n', '谁 画 的 ？|\t谁 画 的 ？\n', '下 下 下 个 女人 是 谁 ？|\t下 一个 是 谁 ？\n', '这 是 谁 ？|\t那 是 谁 ？\n', '这 是 谁 ？|\t这 是 谁 啊 ？\n', '你 很 愚蠢 。|\t你 很 愚蠢 。\n', '你 在 这里 。|\t你 在 这里 。\n', '你 是 我 的 。|\t你 是 我 的 。\n', '你 是 安全 的 。|\t你 是 安全 的 。\n', '你 有病 ！|\t你 有病 ！\n', '我们 能 做到 吗 ？|\t我们 能 做到 吗 ？\n', '你 能 来 吗 ？|\t你 能 来 吗 ？\n', '你 能 阅读 吗 ？|\t你 能 阅读 吗 ？\n', '你 能 游泳 吗 ?|\t你 会 游泳 吗 ?\n', '你 能 游泳 吗 ?|\t你 能 游泳 吗 ？\n', '能 能 你 吗 ？|\t你 能 走 吗 ？\n', '能 你 能 你 吗 ？|\t你们 能 走 吗 ？\n', '你 打 过 电话 了 吗 ？|\t你 打 过 电话 了 吗 ？\n', '您 吸烟 吗 ？|\t你 吸烟 吗 ?\n', '您 吸烟 吗 ？|\t你 抽 不 抽烟 ？\n', '您 吸烟 吗 ？|\t您 吸烟 吗 ？\n', '尽力而为 。|\t尽力而为 。\n', '别 伤心 。|\t别 伤心 。\n', '不要 害羞 。|\t不要 害羞 。\n', '不用麻烦 了 。|\t不用麻烦 了 。\n',  ...
